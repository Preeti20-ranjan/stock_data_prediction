# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
from pandas import datetime

# %%
df=pd.read_csv('C:/Users/hp/Downloads/stock_project.csv',parse_dates=['Date'])

# %%
df.head(10)
# Out:
#         Date       High        Low       Open      Close    Volume  Adj Close
# 0 2010-06-29  25.000000  17.540001  19.000000  23.889999  18766300  23.889999
# 1 2010-06-30  30.420000  23.299999  25.790001  23.830000  17187100  23.830000
# 2 2010-07-01  25.920000  20.270000  25.000000  21.959999   8218800  21.959999
# 3 2010-07-02  23.100000  18.709999  23.000000  19.200001   5139800  19.200001
# 4 2010-07-06  20.000000  15.830000  20.000000  16.110001   6866900  16.110001
# 5 2010-07-07  16.629999  14.980000  16.400000  15.800000   6921700  15.800000
# 6 2010-07-08  17.520000  15.570000  16.139999  17.459999   7711400  17.459999
# 7 2010-07-09  17.900000  16.549999  17.580000  17.400000   4050600  17.400000
# 8 2010-07-12  18.070000  17.000000  17.950001  17.049999   2202500  17.049999
# 9 2010-07-13  18.639999  16.900000  17.389999  18.139999   2680100  18.139999

# %%
df.tail()
# Out:
#            Date        High         Low        Open       Close   Volume  \
# 1635 2016-12-23  213.449997  207.710007  208.000000  213.339996  4670500
# 1636 2016-12-27  222.250000  214.419998  214.880005  219.529999  5915700
# 1637 2016-12-28  223.800003  217.199997  221.529999  219.740005  3782500
# 1638 2016-12-29  219.199997  214.119995  218.559998  214.679993  4045000
# 1639 2016-12-30  217.500000  211.679993  216.300003  213.690002  4642600
#
#        Adj Close
# 1635  213.339996
# 1636  219.529999
# 1637  219.740005
# 1638  214.679993
# 1639  213.690002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640 entries, 0 to 1639
# Data columns (total 7 columns):
# Date         1640 non-null datetime64[ns]
# High         1640 non-null float64
# Low          1640 non-null float64
# Open         1640 non-null float64
# Close        1640 non-null float64
# Volume       1640 non-null int64
# Adj Close    1640 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 89.8 KB

# %%
df.shape
# Out:
# (1640, 7)

# %%
df['Date'].apply(lambda x: x.toordinal())
# Out:
# 0       733952
# 1       733953
# 2       733954
# 3       733955
# 4       733959
# 5       733960
# 6       733961
# 7       733962
# 8       733965
# 9       733966
# 10      733967
# 11      733968
# 12      733969
# 13      733972
# 14      733973
# 15      733974
# 16      733975
# 17      733976
# 18      733979
# 19      733980
# 20      733981
# 21      733982
# 22      733983
# 23      733986
# 24      733987
# 25      733988
# 26      733989
# 27      733990
# 28      733993
# 29      733994
#          ...
# 1610    736285
# 1611    736286
# 1612    736289
# 1613    736290
# 1614    736291
# 1615    736293
# 1616    736296
# 1617    736297
# 1618    736298
# 1619    736299
# 1620    736300
# 1621    736303
# 1622    736304
# 1623    736305
# 1624    736306
# 1625    736307
# 1626    736310
# 1627    736311
# 1628    736312
# 1629    736313
# 1630    736314
# 1631    736317
# 1632    736318
# 1633    736319
# 1634    736320
# 1635    736321
# 1636    736325
# ...

# %%
df['Date'] = df['Date'].apply(lambda x: x.toordinal())

# %%
df.describe()
# Out:
#                 Date         High          Low         Open        Close  \
# count    1640.000000  1640.000000  1640.000000  1640.000000  1640.000000
# mean   735140.363415   130.990183   126.264738   128.700585   128.659506
# std       687.649047    94.737840    91.842670    93.345356    93.315558
# min    733952.000000    16.629999    14.980000    16.139999    15.800000
# 25%    734545.250000    30.247500    28.902500    29.742500    29.539999
# 50%    735141.500000   150.354996   142.715004   147.834999   147.425003
# 75%    735736.250000   220.825001   213.607506   217.367504   217.662495
# max    736328.000000   291.420013   280.399994   287.670013   286.040009
#
#              Volume    Adj Close
# count  1.640000e+03  1640.000000
# mean   4.237622e+06   128.659506
# std    4.338302e+06    93.315558
# min    1.185000e+05    15.800000
# 25%    1.160100e+06    29.539999
# 50%    3.100800e+06   147.425003
# 75%    5.620325e+06   217.662495
# max    3.716390e+07   286.040009

# %%
df
# Out:
#         Date        High         Low        Open       Close    Volume  \
# 0     733952   25.000000   17.540001   19.000000   23.889999  18766300
# 1     733953   30.420000   23.299999   25.790001   23.830000  17187100
# 2     733954   25.920000   20.270000   25.000000   21.959999   8218800
# 3     733955   23.100000   18.709999   23.000000   19.200001   5139800
# 4     733959   20.000000   15.830000   20.000000   16.110001   6866900
# 5     733960   16.629999   14.980000   16.400000   15.800000   6921700
# 6     733961   17.520000   15.570000   16.139999   17.459999   7711400
# 7     733962   17.900000   16.549999   17.580000   17.400000   4050600
# 8     733965   18.070000   17.000000   17.950001   17.049999   2202500
# 9     733966   18.639999   16.900000   17.389999   18.139999   2680100
# 10    733967   20.150000   17.760000   17.940001   19.840000   4195200
# 11    733968   21.500000   19.000000   19.940001   19.889999   3739800
# ...

# %%
df.corr()
# Out:
#                Date      High       Low      Open     Close    Volume  \
# Date       1.000000  0.886453  0.886952  0.886547  0.886537  0.316437
# High       0.886453  1.000000  0.999515  0.999620  0.999688  0.419276
# Low        0.886952  0.999515  1.000000  0.999597  0.999653  0.400302
# Open       0.886547  0.999620  0.999597  1.000000  0.999227  0.410258
# Close      0.886537  0.999688  0.999653  0.999227  1.000000  0.409686
# Volume     0.316437  0.419276  0.400302  0.410258  0.409686  1.000000
# Adj Close  0.886537  0.999688  0.999653  0.999227  1.000000  0.409686
#
#            Adj Close
# Date        0.886537
# High        0.999688
# Low         0.999653
# Open        0.999227
# Close       1.000000
# Volume      0.409686
# Adj Close   1.000000

# %%
df[['Open']].plot()
plt.title('Open Price')
plt.show()


df[['Close']].plot()
plt.title('Close Price')
plt.show()

# %% [markdown]
# ### It can be observed that all  "Open Price"  and "Close Price" has the same trend.

# %%
plt.figure(figsize=(10,5))


plt.subplot(121)
plt.bar(x=df['Date'], height= df['High'],color ='blue', width = 0.4) 
plt.xlabel("Date") 
plt.ylabel("high price") 
plt.title("stock High price from year 2010-16") 
plt.xticks(rotation=80)


plt.subplot(122)
plt.bar(x=df['Date'], height= df['Low'],color ='orange', width = 0.4) 
plt.xlabel("Date") 
plt.ylabel("Low price") 
plt.title("stock low price from year 2010-16") 
plt.xticks(rotation=80)


plt.show()

# %% [markdown]
# ### It can be observed that all  "High Price"  and "Low Price" have some difference .

# %%
df.isnull().sum()
# Out:
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
plt.subplots(figsize=(8,6))
sns.heatmap(df.corr(),annot=True, linewidth=.5,)

# %%
sns.kdeplot(df['High'], color='green', shade=True, Label='high price') 
  
sns.kdeplot(df['Low'], color='red', shade=True, Label='low price') 
  
plt.xlabel('price') 
plt.ylabel('Probability Density')
# Out:
# Text(0,0.5,'Probability Density')

# %%
sns.kdeplot(df['Open'], color='green', shade=True, Label='open price') 
  
sns.kdeplot(df['Close'], color='red', shade=True, Label='close price') 
  
plt.xlabel('price') 
plt.ylabel('Probability Density')
# Out:
# Text(0,0.5,'Probability Density')

# %%
sns.kdeplot(df['Close'], color='green', shade=True, Label='close price') 
  
sns.kdeplot(df['Adj Close'], color='red', shade=True, Label='adjusted close price') 
  
plt.xlabel('price') 
plt.ylabel('Probability Density')
# Out:
# Text(0,0.5,'Probability Density')

# %%
plt.figure(figsize=(15,10))
plt.subplot(231)
plt.scatter(df['Date'],df['High'])
plt.title('')
plt.xlabel('date')
plt.ylabel('High')

plt.subplot(232)
plt.scatter(df['Date'],df['Low'])
plt.title('')
plt.xlabel('date')
plt.ylabel('Low')

plt.subplot(233)
plt.scatter(df['Date'],df['Open'])
plt.title('')
plt.xlabel('date')
plt.ylabel('Open')

plt.subplot(234)
plt.scatter(df['Date'],df['Close'])
plt.title('')
plt.xlabel('date')
plt.ylabel('close')

plt.subplot(235)
plt.scatter(df['Date'],df['Volume'])
plt.title('')
plt.xlabel('date')
plt.ylabel('volume')

plt.subplot(236)
plt.scatter(df['Date'],df['Adj Close'])
plt.title('')
plt.xlabel('date')
plt.ylabel('adj close')

plt.show()

# %%
sns.regplot(x="Date" , y="Close" , data = df)
plt.show()

sns.regplot(x="Date" , y="Open" , data = df)
plt.show()

# %%
plt.plot(df['Date'],df['Adj Close'],'ro')

plt.show()

# %%
from pandas.plotting import lag_plot

# %%
plt.figure(figsize=(10,10))
lag_plot(df['Adj Close'], lag=5)
plt.title('Autocorrelation plot')
# Out:
# Text(0.5,1,'Autocorrelation plot')

# %%
df.corrwith(df.Date).plot.bar()

# %%
df.hist(figsize=(20,10))
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
# multiple linear regression
x=df.iloc[:,3:]
y=df['Adj Close']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=50)
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
regressor=LinearRegression()
regressor.fit(xtrain,ytrain)
ypred_ML=regressor.predict(xtest)
result_ML=regressor.score(xtest,ytest)
print('score',result_ML*100)
# Out:
# score 100.0

# %%
ypred_ML = pd.Series(ypred_ML)
pd.DataFrame(data = {'predicted value': ypred_ML, 'actual value':list(ytest)})
# Out:
#      predicted value  actual value
# 0         198.509995    198.509995
# 1         202.490005    202.490005
# 2          27.320000     27.320000
# 3         182.839996    182.839996
# 4          24.660000     24.660000
# 5         220.169998    220.169998
# 6          28.370001     28.370001
# 7         216.500000    216.500000
# 8         166.369995    166.369995
# 9         208.720001    208.720001
# 10         28.320000     28.320000
# 11        220.990005    220.990005
# 12         22.209999     22.209999
# 13         20.600000     20.600000
# 14        209.970001    209.970001
# 15         21.000000     21.000000
# 16        238.490005    238.490005
# 17         20.719999     20.719999
# 18         31.450001     31.450001
# 19         31.840000     31.840000
# 20         30.010000     30.010000
# 21        251.449997    251.449997
# 22        147.649994    147.649994
# 23         35.330002     35.330002
# 24        196.940002    196.940002
# 25         50.189999     50.189999
# ...

# %%
#Random forest


random=RandomForestRegressor(max_depth=2,random_state=0)
random.fit(xtrain,ytrain)
res=random.score(xtest,ytest)
ypred_RF=random.predict(xtest)
print('result',res*100)
# Out:
# result 97.58321411955968

# %%
ypred_RF = pd.Series(ypred_RF)
pd.DataFrame(data = {'predicted value': ypred_RF, 'actual value':list(ytest)})
# Out:
#      predicted value  actual value
# 0         185.733980    198.509995
# 1         196.866127    202.490005
# 2          29.448182     27.320000
# 3         179.646842    182.839996
# 4          29.448182     24.660000
# 5         232.911875    220.169998
# 6          29.448182     28.370001
# 7         232.911875    216.500000
# 8         179.646842    166.369995
# 9         207.762093    208.720001
# 10         29.448182     28.320000
# 11        232.911875    220.990005
# 12         29.448182     22.209999
# 13         29.448182     20.600000
# 14        217.953227    209.970001
# 15         29.448182     21.000000
# 16        232.911875    238.490005
# 17         29.448182     20.719999
# 18         29.448182     31.450001
# 19         29.448182     31.840000
# 20         29.448182     30.010000
# 21        232.911875    251.449997
# 22        179.646842    147.649994
# 23         29.448182     35.330002
# 24        179.646842    196.940002
# 25         29.448182     50.189999
# ...

# %%
# Decision tree


from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
dt_regressor=DecisionTreeRegressor(max_depth=15)
dt_regressor.fit(xtrain,ytrain)
ypred_DT=dt_regressor.predict(xtest)
res_DT=dt_regressor.score(xtest,ytest)
print('result:',res_DT*100)
# Out:
# result: 99.99723637529088

# %%
ypred_RF = pd.Series(ypred_RF)
pd.DataFrame(data = {'predicted value': ypred_RF, 'actual value':list(ytest)})
# Out:
#      predicted value  actual value
# 0         185.733980    198.509995
# 1         196.866127    202.490005
# 2          29.448182     27.320000
# 3         179.646842    182.839996
# 4          29.448182     24.660000
# 5         232.911875    220.169998
# 6          29.448182     28.370001
# 7         232.911875    216.500000
# 8         179.646842    166.369995
# 9         207.762093    208.720001
# 10         29.448182     28.320000
# 11        232.911875    220.990005
# 12         29.448182     22.209999
# 13         29.448182     20.600000
# 14        217.953227    209.970001
# 15         29.448182     21.000000
# 16        232.911875    238.490005
# 17         29.448182     20.719999
# 18         29.448182     31.450001
# 19         29.448182     31.840000
# 20         29.448182     30.010000
# 21        232.911875    251.449997
# 22        179.646842    147.649994
# 23         29.448182     35.330002
# 24        179.646842    196.940002
# 25         29.448182     50.189999
# ...

# %%
# SVM
from sklearn.svm import SVR
from sklearn.metrics import r2_score
svr=SVR(epsilon=1,kernel='poly',degree=3)
svr.fit(xtrain,ytrain)
ypred_svr=svr.predict(xtest)
result_svr=svr.score(xtest,ytest)
print('result:',result_svr*100)
# Out:
# result: 87.50752402807704

# %%
ypred_svr = pd.Series(ypred_svr)
pd.DataFrame(data = {'predicted value': ypred_svr, 'actual value':list(ytest)})
# Out:
#      predicted value  actual value
# 0         162.801766    198.509995
# 1         156.603003    202.490005
# 2          31.708156     27.320000
# 3         146.161867    182.839996
# 4          23.646177     24.660000
# 5         234.837540    220.169998
# 6          33.314134     28.370001
# 7         187.923003    216.500000
# 8         134.932622    166.369995
# 9         163.604656    208.720001
# 10         34.499452     28.320000
# 11        187.329532    220.990005
# 12         10.204946     22.209999
# 13          6.596436     20.600000
# 14        246.985804    209.970001
# 15          9.639393     21.000000
# 16        240.160341    238.490005
# 17          3.844836     20.719999
# 18         36.757834     31.450001
# 19         41.039054     31.840000
# 20         33.301740     30.010000
# 21        267.631820    251.449997
# 22        129.580725    147.649994
# 23         53.731621     35.330002
# 24        152.053859    196.940002
# 25         87.635494     50.189999
# ...

# %%
print('score of Multiple Linear regression is ',result_ML*100)
print('score of Random Forest is  ',res*100)
print('score of Decision Tree  is ',res_DT*100)
print('score of Support Vector is ',result_svr*100)
# Out:
# score of Multiple Linear regression is  100.0
# score of Random Forest is   97.58321411955968
# score of Decision Tree  is  99.99723637529088
# score of Support Vector is  87.50752402807704
